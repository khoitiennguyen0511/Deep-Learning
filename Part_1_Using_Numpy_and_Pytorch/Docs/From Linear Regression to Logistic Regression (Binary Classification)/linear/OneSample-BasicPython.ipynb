# %%
# plot data
import matplotlib.pyplot as plt

areas  = [6.7, 4.6, 3.5, 5.5]
prices = [9.1, 5.9, 4.6, 6.7]
N = len(areas)

plt.scatter(areas, prices)
plt.xlabel('Area (x 100$m^2$)')
plt.ylabel('Price (Tael)')
plt.xlim(3,7)
plt.ylim(4,10)
plt.show()

# %% [markdown]
# ####  Implementation

# %%
# shuffle data
def shuffle_data(X, y):
    zip_data = list(zip(X, y))
    random.shuffle(zip_data)
    X_shuffled, y_shuffled = zip(*zip_data)

    return X_shuffled, y_shuffled

# forward
def predict(x, w, b):
    return x*w + b

# compute gradient
def gradient(y_hat, y, x):
    dw = 2*x*(y_hat-y)
    db = 2*(y_hat-y)
    
    return (dw, db)

# update weights
def update_weight(w, b, lr, dw, db):
    w_new = w - lr*dw
    b_new = b - lr*db
    
    return (w_new, b_new)

# %%
# data preparation
import numpy as np
import matplotlib.pyplot as plt

x_data = [6.7, 4.6, 3.5, 5.5]
y_data = [9.1, 5.9, 4.6, 6.7]
N = len(x_data)

print(f'areas: {x_data}')
print(f'prices: {y_data}')
print(f'data_size: {N}')
# Out:
# areas: [6.7, 4.6, 3.5, 5.5]
# prices: [9.1, 5.9, 4.6, 6.7]
# data_size: 4

# %%
# init weights
b = 0.04
w = -0.34
lr = 0.005

# parameter
epoch_max = 30
losses = [] # monitoring

for epoch in range(epoch_max):
    # shuffle data
    x_data_sh, y_data_sh = shuffle_data(x_data, y_data)
    
    # for an epoch    
    for i in range(N):
        
        # get a sample
        x = x_data_sh[i]
        y = y_data_sh[i]      
        
        # predict y_hat
        y_hat = predict(x, w, b)

        # compute loss
        loss = (y_hat-y)*(y_hat-y)
        
        # for debug
        losses.append(loss)
        print(loss)

        # compute gradient
        (dw, db) = gradient(y_hat, y, x)

        # update weights
        (w, b) = update_weight(w, b, lr, dw, db)
# Out:
# 64.275122
# 7.281875925251284
# 2.7034647567167442
# 3.8199153445238667
# 1.8055068620601096
# 0.5753017794212366
# 0.6760647529148198
# 1.9098865405316419
# 0.04011086299347785
# 0.46794456324073264
# 0.07880693262030053
# 0.0012135140992188696
# 0.04002125504071177
# 0.0034473519436782167
# 0.2755432054350275
# 0.004576927325415734
# 0.09034623352356415
# 0.04218993802011579
# 0.1581725598209178
# 0.0002729137247217423
# 0.0002053829292501141
# 0.07138389546101939
# 0.23736736422669175
# 0.01816355390936699
# 0.09394862564907423
# 0.20129605760123392
# 0.007130224435723581
# 0.0005785369912026274
# 0.0004353816285857422
# 0.1395189174879114
# 0.03129443313143894
# 0.13838617661390298
# 0.06540909129016487
# 0.002298568203264231
# 0.23453324859399446
# 0.01819786199146765
# 0.0028889888040954156
# 0.10119654595835133
# 0.038824166341858576
# 0.15293001225487463
# 0.07228332610484321
# 0.0004073834099376421
# 0.0015578173120524455
# 0.219525545639383
# 0.006450886606907564
# 0.015974921810385095
# 0.10625930622241124
# 0.19076052663148885
# 0.02299156525146787
# 0.12218029389985749
# 0.1737907558052865
# 0.008846765325231964
# 0.14368202024526103
# 0.001846905979265672
# 0.16460772680918856
# 0.00934810684845388
# 0.14690572761496104
# 0.002044426357392413
# 2.1662830472767e-06
# 0.1618245880653387
# 0.026716219885534045
# 0.004778836689597996
# 0.12053944845578737
# 0.17471848628274905
# 0.15753135266026574
# 0.00013203528532703527
# 0.0025759739667722352
# 0.1563119955552061
# 0.04576646569213253
# 0.0544682495421915
# 0.01217776057324504
# 0.16328578672503907
# 0.0031946587155119257
# 1.796488791923405e-05
# 0.15129790669030907
# 0.16753568788517406
# 0.07918678997697676
# 0.0002136181805619092
# 0.0014891804278337284
# 0.20959975491689603
# 0.061368546658311755
# 0.22294601066748906
# 0.009129054387286386
# 0.0007331356000125053
# 0.08643974051774606
# 0.21258210198467556
# 0.005880322002717726
# 0.0158804786077206
# 0.10756558149428885
# 0.0004597004862326614
# 0.00024031091042815643
# 0.18676116984911198
# 0.054681655378797274
# 0.05017056715457194
# 0.010667677694771349
# 0.15840593226457117
# 0.0027056518486066957
# 0.15229722846803864
# 0.1661843663109766
# 0.00016835790728526268
# 0.00012669879536444703
# 0.0028419775266093758
# 0.0682969618324297
# 0.23742999582537125
# 0.13256880787926262
# 0.0010275490287640166
# 0.16947427508325041
# 0.007798139809748464
# 0.01983748806777308
# 0.0027585382625888496
# 0.09120746771083255
# 0.19932221051516968
# 0.000840761356461581
# 0.005531674291381412
# 0.13188102804793322
# 0.17552703340480466
# 0.12608105092675517
# 0.010651167856430348
# 0.02515433309561107
# 0.12947114481806674

# %%
# get result 
print(w, b)
# Out:
# 1.2323144603898835 0.2721142781279238

# %%
import matplotlib.pyplot as plt
plt.plot(losses)

# %%
import matplotlib.pyplot as plt
plt.plot(losses[-10:])

# %%
area_real = 6
predicted_price = area_real*w + b
print('predicted_price: ', predicted_price)
# Out:
# predicted_price:  7.666001040467225

# %%
#x_data = range(2, 8)
y_data = [x*w + b for x in x_data]
plt.plot(x_data, y_data, 'r')
plt.scatter(areas, prices)
